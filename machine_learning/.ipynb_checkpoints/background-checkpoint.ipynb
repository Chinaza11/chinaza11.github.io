# %% [markdown]
# # Background

# %% [markdown]
# <big>
# This was the capstone project for a machine learning class I took. The class covered the mathematical foundation of several machine learning models and during the course of the class, I had to build several machine learning models from scratch including principal component analysis (PCA), linear regression, logistic regression, and artificial neural network (ANN) models.
#
# For the capstone project, I was given a dataset by the instructor and had to evaluate the models I built during the course of the class on the dataset. I also had to apply existing Scikit-learn packages that implement these models. This allowed me to validate the results I got using the models I built from scratch by comparing their results to those obtained using Scikit-learn packages.
#
# This class gave me a solid background and introduction to machine learning models.
#
# </big>

# %% [markdown]
# <br>

# %% [markdown]
# ## About data:

# %% [markdown]
# <big> The data comprised 863 samples, 15606 independent variables, and two classes of target variables (0/1). </big>

# %% [markdown]
# <br>

# %% [markdown]
# ### Independent variables

# %%
import pandas as pd

df_x = pd.read_csv("C:/Users/nnamd/Documents/data/machine_learning/sandbox_3/sample_data_for_project_final.csv")
df_x
# Out:
#            Unnamed: 0      sample_1      sample_2      sample_3      sample_4  \
# 0          variable_1  1.335571e+05  4.067772e+05  4.653638e+05  2.327503e+05
# 1          variable_2  2.914323e+08  2.058200e+08  1.572093e+08  1.889364e+08
# 2          variable_3  1.039778e+08  6.959067e+07  6.546160e+07  7.890295e+07
# 3          variable_4  1.899937e+07  2.725515e+07  5.049965e+07  3.885274e+07
# 4          variable_5  1.075189e+04  1.365641e+02  5.717232e+03  1.365641e+02
# ...               ...           ...           ...           ...           ...
# 15601  variable_15602  1.365641e+02  1.365641e+02  1.365641e+02  1.365641e+02
# 15602  variable_15603  1.484041e+04  1.365641e+02  8.670437e+03  1.365641e+02
# 15603  variable_15604  3.509693e+03  6.338602e+03  9.574115e+03  1.731127e+03
# 15604  variable_15605  1.365641e+02  2.799276e+03  6.296987e+03  1.365641e+02
# 15605  variable_15606  1.365641e+02  1.365641e+02  1.365641e+02  1.365641e+02
#
# ...

# %% [markdown]
# <br>

# %% [markdown]
# ### Target variables

# %%
df_y = pd.read_csv("C:/Users/nnamd/Documents/data/machine_learning/sandbox_3/sample_metadata_for_project_final.csv")
df_y
# Out:
#     sample_name  sample_label
# 0      sample_1             0
# 1      sample_2             1
# 2      sample_3             0
# 3      sample_4             1
# 4      sample_5             0
# ..          ...           ...
# 858  sample_860             1
# 859  sample_861             0
# 860  sample_862             1
# 861  sample_863             0
# 862  sample_864             1
#
# [863 rows x 2 columns]

# %% [markdown]
# <br>

# %% [markdown]
# ## Project Goals:
#
# <big>
# => Dimensionality reduction of data using PCA and extraction of interesting principal components.
#
# => Using extracted principal components to build logistic regression and ANN models to predict the target variables in the data.
#
# <br>
#
# - The next pages will show the application of PCA, logistic regression, and ANN models.
#
# </big>
